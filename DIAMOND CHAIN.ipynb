# %%
import pandas as pd
import pdfplumber

# %%
with pdfplumber.open(r"C:\Users\datma003\Desktop\Untitled Folder\DIAMOND CHAIN NEW LIST EFFECTIVE FROM 2nd   MAY 2022 (2).pdf") as pdf:
    tables = []
    for page in pdf.pages:
        tables.extend(page.extract_tables())

for i, table in enumerate(tables):
        print(f"Table {i}:")
        for row in table:
            print(row)
        print("\n")
# Out:
# Table 0:
# ['BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', None, None, None, None, None, None]
# ['Diamond Chain\nPart No', 'Description\n( Pitch x WIP )', None, 'MRP\nPer Metre', 'MRP per No\n(3.048 mts 10 ft length)', 'Spares MRP Per Number', None]
# [None, None, None, None, None, 'CL', 'SZL']
# ['Part No.', 'in mm', 'in inches', 'Rs. P.', 'Rs. P.', 'Rs. P.', 'Rs. P.']
# ['SINGLE STRAND', None, None, None, None, None, None]
# ['D04B01', '6.0 x 2.8', '', '1579.00', '4813.00', '31.00', '']
# ['D05B01', '8.0 X 3.0', '', '1147.00', '3486.00', '28.00', '']
# ['D06101', '9.53 x 5.72', '3/8 x 7/32', '557.00', '1703.00', '20.00', '30.00']
# ['D08001', '12.70 x 3.30', '1/2 x 1/8', '336.00', '1019.00', '18.00', '21.00']
# ['D08101', '12.70 x 4.88', '1/2 x 3/16', '572.00', '1741.00', '20.00', '21.00']
# ['D08201', '12.70 x 5.21', '1/2 x 0.205', '867.00', '2640.00', '30.00', '46.00']
# ['D08301', '12.70 x 7.75', '1/2 x 5/16', '630.00', '1913.00', '32.00', '46.00']
# ...

# %%
table_0=tables[0]+tables[1]
table_1=tables[2]+tables[3]+tables[4]
table_2=tables[5]
table_3=tables[6]
table_4=tables[7]
table_5=tables[8]
table_6=tables[9]
table_7=tables[10]+tables[11]
table_8=tables[12]

##Merge the tables which come under the same category/title

# %%
tables=[table_0,table_1,table_2,table_3,table_4,table_5,table_6,table_7,table_8]

for table in tables:
    title_name = table[0][0]  # Extract title name from the first element of the first nested list
    # Iterate over each nested list in the table, excluding the first one (title)
    for nested_list in table[1:]:
        nested_list.insert(1, title_name)  # Insert title name at index position 1

# Print the updated tables for verification
for i, table in enumerate(tables, 1):
    print(f"Table {i}:")
    for nested_list in table:
        print(nested_list)
# Out:
# Table 1:
# ['BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', None, None, None, None, None, None]
# ['Diamond Chain\nPart No', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'Description\n( Pitch x WIP )', None, 'MRP\nPer Metre', 'MRP per No\n(3.048 mts 10 ft length)', 'Spares MRP Per Number', None]
# [None, 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', None, None, None, None, 'CL', 'SZL']
# ['Part No.', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'in mm', 'in inches', 'Rs. P.', 'Rs. P.', 'Rs. P.', 'Rs. P.']
# ['SINGLE STRAND', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', None, None, None, None, None, None]
# ['D04B01', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', '6.0 x 2.8', '', '1579.00', '4813.00', '31.00', '']
# ['D05B01', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', '8.0 X 3.0', '', '1147.00', '3486.00', '28.00', '']
# ...

# %%
titles=[]
for i in range(0,len(tables)):
    a=tables[i][0][0]
    titles.append(a)
titles
# Out:
# ['BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#  'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1',
#  'STAINLESS STEEL STD ROLLER CHAINS',
#  'HOLLOW BEARING PIN CHAINS',
#  'CARDING CHAIN',
#  'DELTA CHAINS',
#  'BUSH CHAINS',
#  'LEAF CHAIN',
#  'EXTENDED PITCH CHAIN']

# %%
for i in range(9):
    table_name = f"table_{i}"
    table = globals()[table_name]  # Assuming tables are defined as variables
    
    # Filter out unwanted lists
    filtered_table = [row for row in table if not any(row[0] == name or row[0] is None or row[0].startswith('Diamond') or row[0].startswith('Part No.') or row[0].startswith('Model') for name in titles)]
    
    # Update the table with filtered data
    globals()[table_name] = filtered_table

#Filtered unneccessary data.

# %%
tables=[table_0,table_1,table_2,table_3,table_4,table_5,table_6,table_7,table_8]
tables
# Out:
# [[['SINGLE STRAND',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   ['D04B01',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '6.0 x 2.8',
#    '',
#    '1579.00',
#    '4813.00',
#    '31.00',
#    ''],
#   ['D05B01',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '8.0 X 3.0',
#    '',
#    '1147.00',
#    '3486.00',
#    '28.00',
#    ''],
#   ['D06101',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '9.53 x 5.72',
#    '3/8 x 7/32',
#    '557.00',
#    '1703.00',
#    '20.00',
#    '30.00'],
#   ['D08001',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '12.70 x 3.30',
#    '1/2 x 1/8',
#    '336.00',
#    '1019.00',
#    '18.00',
#    '21.00'],
#   ['D08101',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '12.70 x 4.88',
# ...

# %%
strand_types=['SINGLE STRAND','DOUBLE STRAND', 'TRIPLE STRAND','DUPLEX','TRIPLEX','FOUR STRAND','FIVE STRAND','SIX STRAND',
             'AMERICAN HEAVY - SIMPLEX "SINGLE"','AMERICAN HEAVY - DUPLEX "DOUBLE"','SINGLE STRAND: BS ROLLER CHAINS','AMERICAN STANDARD: SIMPLEX','DOUBLESTRAND','']

# %%
table_2,table_3,table_4,table_7,table_8  ## Have no specific strand types
strand_tables=[table_0,table_1,table_5,table_6]
strand_tables
# Out:
# [[['SINGLE STRAND',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   ['D04B01',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '6.0 x 2.8',
#    '',
#    '1579.00',
#    '4813.00',
#    '31.00',
#    ''],
#   ['D05B01',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '8.0 X 3.0',
#    '',
#    '1147.00',
#    '3486.00',
#    '28.00',
#    ''],
#   ['D06101',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '9.53 x 5.72',
#    '3/8 x 7/32',
#    '557.00',
#    '1703.00',
#    '20.00',
#    '30.00'],
#   ['D08001',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '12.70 x 3.30',
#    '1/2 x 1/8',
#    '336.00',
#    '1019.00',
#    '18.00',
#    '21.00'],
#   ['D08101',
#    'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228',
#    '12.70 x 4.88',
# ...

# %%
#Table_0 : British (single,double and triple strands)

single_strand_lists_British = []
double_strand_lists_British = []
triple_strand_lists_British = []

current_category = None

for sublist in table_0:
    if sublist[0] == 'SINGLE STRAND':
        current_category = single_strand_lists_British
    elif sublist[0] == 'DOUBLE STRAND':
        current_category = double_strand_lists_British
    elif sublist[0] == 'TRIPLE STRAND':
        current_category = triple_strand_lists_British
    else:
        current_category.append(sublist)

# Print or use the segregated lists
print("Single Strand Lists:")
for sublist in single_strand_lists_British:
    print(sublist)
print()

print("Double Strand Lists:")
for sublist in double_strand_lists_British:
    print(sublist)
print()

print("Triple Strand Lists:")
for sublist in triple_strand_lists_British:
    print(sublist)
# Out:
# Single Strand Lists:
# ['D04B01', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', '6.0 x 2.8', '', '1579.00', '4813.00', '31.00', '']
# ['D05B01', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', '8.0 X 3.0', '', '1147.00', '3486.00', '28.00', '']
# ['D06101', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', '9.53 x 5.72', '3/8 x 7/32', '557.00', '1703.00', '20.00', '30.00']
# ['D08001', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', '12.70 x 3.30', '1/2 x 1/8', '336.00', '1019.00', '18.00', '21.00']
# ['D08101', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', '12.70 x 4.88', '1/2 x 3/16', '572.00', '1741.00', '20.00', '21.00']
# ['D08201', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', '12.70 x 5.21', '1/2 x 0.205', '867.00', '2640.00', '30.00', '46.00']
# ...

# %%
len(single_strand_lists_British),len(double_strand_lists_British),len(triple_strand_lists_British)
# Out:
# (21, 13, 12)

# %%
# dict0 is for british title and all different strands 

#Assuming the dictionary is already defined
dict0 = {'ID': [], 'Title': [], "Description": {"In mm":[],"In Inches":[]}, "Price per metre": [], "Attributes": {"Strand Type":[],"Price Per 10ft length": [],"Spares MRP per number":{"CL":[],"SZL":[]}}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists, strand_type):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict0['ID'].append(sublist[0])
        dict0['Title'].append(sublist[1])
        dict0['Description']['In mm'].append(sublist[2])
        dict0['Description']['In Inches'].append(sublist[3])
        dict0['Price per metre'].append(sublist[4])
        # Adding Strand Type
        dict0['Attributes']['Strand Type'].append(strand_type)
        dict0['Attributes']['Price Per 10ft length'].append(sublist[5])
        dict0['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
        dict0['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])
# Adding values from single_strand_lists
add_values_to_dict(single_strand_lists_British, 'single_strand')

# Adding values from double_strand_lists
add_values_to_dict(double_strand_lists_British, 'double_strand')

# Adding values from triple_strand_lists
add_values_to_dict(triple_strand_lists_British, 'triple_strand')

# Printing the updated dictionary
print(dict0)
# Out:
# {'ID': ['D04B01', 'D05B01', 'D06101', 'D08001', 'D08101', 'D08201', 'D08301', 'D08701', 'D08801', 'D08901', 'D10001', 'D10101', 'D12001', 'D16001', 'D20001', 'D24001', 'D28001', 'D32001', 'D32301', 'D40001', 'D48001', 'D05B02', 'D06102', 'D08302', 'D10102', 'D12002', 'D16002', 'D20002', 'D24002', 'D28002', 'D32002', 'D32302', 'D40002', 'D48002', 'D06103', 'D08303', 'D10103', 'D12003', 'D16003', 'D20003', 'D24003', 'D28003', 'D32003', 'D32303', 'D40003', 'D48003'], 'Title': ['BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN 8187/ISO 606 / BS 228', 'BRITISH STRANDARD CHAINS UPTO 3" PITCH DIN
# ...

# %%
#Table_1 : American (single,duplex, triplex, four, five, six, single, double)

single_strand_lists_American = []
duplex_American = []
triplex_American = []
four_strand_lists_American = []
five_strand_lists_American = []
six_strand_lists_American = []
simplex_single_American = []
duplex_double_American = []

current_category = None

for sublist in table_1:
    if sublist[0] == 'SINGLE STRAND':
        current_category = single_strand_lists_American
    elif sublist[0] == 'DUPLEX':
        current_category = duplex_American
    elif sublist[0] == 'TRIPLEX':
        current_category = triplex_American
    elif sublist[0] == 'FOUR STRAND':
        current_category = four_strand_lists_American
    elif sublist[0] == 'FIVE STRAND':
        current_category = five_strand_lists_American
    elif sublist[0] == 'SIX STRAND':
        current_category = six_strand_lists_American
    elif sublist[0] == 'AMERICAN HEAVY - SIMPLEX "SINGLE"':
        current_category = simplex_single_American  
    elif sublist[0] == 'AMERICAN HEAVY - DUPLEX "DOUBLE"':
        current_category = duplex_double_American 
    else:
        current_category.append(sublist)

# Print or use the segregated lists
print("Single Strand Lists:")
for sublist in single_strand_lists_American:
    print(sublist)
print()

print("Duplex Strand Lists:")
for sublist in duplex_American:
    print(sublist)
print()

print("Triplex Lists:")
for sublist in triplex_American:
    print(sublist)

# print(len(single_strand_lists_American))
# print(len(duplex_American))
# print(len(triplex_American))
# print(len(four_strand_lists_American))
# print(len(five_strand_lists_American))
# print(len(six_strand_lists_American))
# print(len(simplex_single_American))
# print(len(duplex_double_American))
# Out:
# Single Strand Lists:
# ['D08A01', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', '12.70 x 7.85', '1/2 x 5/16', '725.00', '2213.00', '30.00', '47.00']
# ['D08D01', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', '12.70 x 6.25', '1/2 x 0.25', '582.00', '1772.00', '21.00', '32.00']
# ['D10201', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', '15.88 x 9.40', '5/8 x 3/8', '906.00', '2762.00', '46.00', '66.00']
# ['D12101', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', '19.05 x 12.58', '3/4 x 1/2', '1483.00', '4515.00', '86.00', '128.00']
# ['D16101', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', '25.40 x 15.75', '1 x 5/8', '2206.00', '6719.00', '133.00', '236.00']
# ['D20101', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', '31.75 x 18.90', '1¼ x 3/4', '3310.00', '10091.00', '309.00', '493.00']
# ...

# %%
# dict1 is for american title and all different strands 


dict1 = {'ID': [], 'Title': [], "Description": {"In mm":[],"In Inches":[]}, "Price per metre": [], "Attributes": {"Strand Type":[],"Price Per 10ft length": [],"Spares MRP per number":{"CL":[],"SZL":[]}}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists, strand_type):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict1['ID'].append(sublist[0])
        dict1['Title'].append(sublist[1])
        dict1['Description']['In mm'].append(sublist[2])
        dict1['Description']['In Inches'].append(sublist[3])
        dict1['Price per metre'].append(sublist[4])
        # Adding Strand Type
        dict1['Attributes']['Strand Type'].append(strand_type)
        dict1['Attributes']['Price Per 10ft length'].append(sublist[5])
        dict1['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
        dict1['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])

add_values_to_dict(single_strand_lists_American, 'single_strand')
add_values_to_dict(duplex_American, 'duplex')
add_values_to_dict(triplex_American, 'triplex')
add_values_to_dict(four_strand_lists_American, 'four strand')
add_values_to_dict(five_strand_lists_American, 'five strand')
add_values_to_dict(six_strand_lists_American, 'six strand')
add_values_to_dict(simplex_single_American, 'simplex single')
add_values_to_dict(duplex_double_American, 'duplex double')

# Printing the updated dictionary
print(dict1)
# Out:
# {'ID': ['D08A01', 'D08D01', 'D10201', 'D12101', 'D16101', 'D20101', 'D24101', 'D28101', 'D32101', 'D40101', 'D48101', 'D08A02', 'D10202', 'D12102', 'D16102', 'D20102', 'D24102', 'D28102', 'D32102', 'D40102', 'D48102', 'D08A03', 'D10203', 'D12103', 'D16103', 'D20103', 'D24103', 'D28103', 'D32103', 'D40103', 'D48103', 'D10204', 'D12104', 'D16104', 'D20104', 'D24104', 'D28104', 'D32104', 'D10205', 'D12105', 'D16105', 'D20105', 'D24105', 'D28105', 'D32105', 'D10206', 'D12106', 'D16106', 'D20106', 'D24106', 'D28106', 'D32106', 'D12201', 'D16201', 'D20201', 'D24201', 'D28201', 'D32201', 'D12202', 'D16202', 'D20202', 'D24202', 'D28202', 'D32202'], 'Title': ['AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 8188/ISO 606 / ANSI B 29.1', 'AMERICAN STANDARD CHAINS UPTO 3" PITCH DIN 818
# ...

# %%
#Table_2 : Stainless Steel No Strand Type

# dict2 is for Stainless steel 


dict2 = {'ID': [], 'Title': [], "Description": {"In mm":[],"In Inches":[]}, "Price per metre": [], "Attributes": {"Price Per 10ft length": []}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict2['ID'].append(sublist[0])
        dict2['Title'].append(sublist[1])
        dict2['Description']['In mm'].append(sublist[2])
        dict2['Description']['In Inches'].append(sublist[3])
        dict2['Price per metre'].append(sublist[4])
        # Adding Strand Type
#         dict3['Attributes']['Strand Type'].append(strand_type)
        dict2['Attributes']['Price Per 10ft length'].append(sublist[5])
#         dict3['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
#         dict3['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])

add_values_to_dict(table_2)


# Printing the updated dictionary
print(dict2)
# Out:
# {'ID': ['D05B 01 SS01', 'D061 01 SS01', 'D083 01 SS01', 'D101 01 SS01', 'D120 01 SS01', 'D160 01 SS01', 'B06A 01 SS01', 'D08A 01 SS01', 'D102 01 SS01', 'D121 01 SS01', 'D161 01 SS01'], 'Title': ['STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS'], 'Description': {'In mm': ['8.0 X 3.0', '9.53 x 5.72', '12.70 x 7.75', '15.88 x 9.65', '19.05 x 11.68', '25.40 x 17.02', '9.53 x 4.68', '12.70 x 7.85', '15.88 x 9.40', '19.05 x 12.58', '25.40 x 15.75'], 'In Inches': ['', '3/8 x 7/32', '1/2 x 5/16', '5/8 x 3/8', '3/4 x 7/16', '1 x 11/16', '3/8 x 3/16', '1/2 x 5/16', '5/8 x 3/8', '3/4 x 1/2', '1 x 5/8']}, 'Price per metre': ['2020.00', '2220.00'
# ...

# %%
#Table_3 : Hollow Bearing

# dict2 is for Hollow Bearing

dict3 = {'ID': [], 'Title': [], "Description": {"In mm":[],"In Inches":[]}, "Price per metre": [], "Attributes": {"Price Per 10ft length": []}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict3['ID'].append(sublist[0])
        dict3['Title'].append(sublist[1])
        dict3['Description']['In mm'].append(sublist[2])
        dict3['Description']['In Inches'].append(sublist[3])
        dict3['Price per metre'].append(sublist[4])
        # Adding Strand Type
#         dict3['Attributes']['Strand Type'].append(strand_type)
        dict3['Attributes']['Price Per 10ft length'].append(sublist[5])
#         dict3['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
#         dict3['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])

add_values_to_dict(table_3)


# Printing the updated dictionary
print(dict3)

#-----------------------------------------------------
# Out:
# {'ID': ['D061 01 HP01', 'D083 01 HP01', 'D102 01 HP01', 'D120 01 HP01', 'D160 01 HP01', 'D083 01 HP02', 'D101 01 HP02', 'D120 01 HP02', 'D160 01 HP02'], 'Title': ['HOLLOW BEARING PIN CHAINS', 'HOLLOW BEARING PIN CHAINS', 'HOLLOW BEARING PIN CHAINS', 'HOLLOW BEARING PIN CHAINS', 'HOLLOW BEARING PIN CHAINS', 'HOLLOW BEARING PIN CHAINS', 'HOLLOW BEARING PIN CHAINS', 'HOLLOW BEARING PIN CHAINS', 'HOLLOW BEARING PIN CHAINS'], 'Description': {'In mm': ['9.53 x 5.72', '12.70 x 7.75', '15.88 x 9.40', '19.05 x 11.68', '25.40 x 17.02', '12.70 x 7.75', '15.88 x 9.65', '19.05 x 11.68', '25.40 x 17.02'], 'In Inches': ['3/8 x 7/32', '1/2 x 5/16', '5/8 x 3/8', '3/4 x 7/16', '1 x 11/16', '1/2 x 5/16', '5/8 x 3/8', '3/4 x 7/16', '1 x 11/16']}, 'Price per metre': ['439.00', '778.00', '887.00', '823.00', '1734.00', '577.00', '688.00', '953.00', '3481.00'], 'Attributes': {'Price Per 10ft length': ['1338.00', '2367.00', '2706.00', '2511.00', '5286.00', '1754.00', '2092.00', '2899.00', '10608.00']}}

# %%
# Function to add values to the dictionary
def add_values_to_dict(dictionary, strand_lists):
    for sublist in strand_lists:
        # Append values to the dictionary
        dictionary['ID'].append(sublist[0])
        dictionary['Title'].append(sublist[1])
        dictionary['Description']['In mm'].append(sublist[2])
        dictionary['Description']['In Inches'].append(sublist[3])
        dictionary['Price per metre'].append(sublist[4])
        # Adding Strand Type
        # dictionary['Attributes']['Strand Type'].append(strand_type)
        dictionary['Attributes']['Price Per 10ft length'].append(sublist[5])
        # dictionary['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
        # dictionary['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])

# Table_2: Stainless Steel No Strand Type
dict2 = {'ID': [], 'Title': [], "Description": {"In mm":[],"In Inches":[]}, "Price per metre": [], "Attributes": {"Price Per 10ft length": []}}
add_values_to_dict(dict2, table_2)

# Dict2 - Stainless stel
print(dict2)
print("\n")
# Table_3: Hollow Bearing
dict3 = {'ID': [], 'Title': [], "Description": {"In mm":[],"In Inches":[]}, "Price per metre": [], "Attributes": {"Price Per 10ft length": []}}
add_values_to_dict(dict3, table_3)

# Dict3 - Hollow Bearing
print(dict3)
# Out:
# {'ID': ['D05B 01 SS01', 'D061 01 SS01', 'D083 01 SS01', 'D101 01 SS01', 'D120 01 SS01', 'D160 01 SS01', 'B06A 01 SS01', 'D08A 01 SS01', 'D102 01 SS01', 'D121 01 SS01', 'D161 01 SS01'], 'Title': ['STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS', 'STAINLESS STEEL STD ROLLER CHAINS'], 'Description': {'In mm': ['8.0 X 3.0', '9.53 x 5.72', '12.70 x 7.75', '15.88 x 9.65', '19.05 x 11.68', '25.40 x 17.02', '9.53 x 4.68', '12.70 x 7.85', '15.88 x 9.40', '19.05 x 12.58', '25.40 x 15.75'], 'In Inches': ['', '3/8 x 7/32', '1/2 x 5/16', '5/8 x 3/8', '3/4 x 7/16', '1 x 11/16', '3/8 x 3/16', '1/2 x 5/16', '5/8 x 3/8', '3/4 x 1/2', '1 x 5/8']}, 'Price per metre': ['2020.00', '2220.00'
# ...

# %%
#Table_4 : Carding Chain


dict4 = {'ID': [], 'Title': [], "Description (Pitch X WIP)": [], "Price per metre": [], "Attributes": {"Carding Machine": []}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict4['ID'].append(sublist[0])
        dict4['Title'].append(sublist[1])
        dict4['Description (Pitch X WIP)'].append(sublist[2])
        #dict4['Description']['In Inches'].append(sublist[3])
        dict4['Price per metre'].append(sublist[4])
        # Adding Strand Type
#         dict3['Attributes']['Strand Type'].append(strand_type)
        dict4['Attributes']['Carding Machine'].append(sublist[3])
#         dict3['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
#         dict3['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])

add_values_to_dict(table_4)


# Printing the updated dictionary
print(dict4)
# Out:
# {'ID': ['C23101', 'C23301', 'C23401', 'C23401', 'C23501', 'C23501', 'C23601', 'C36522', 'SP1976', 'SP1807'], 'Title': ['CARDING CHAIN', 'CARDING CHAIN', 'CARDING CHAIN', 'CARDING CHAIN', 'CARDING CHAIN', 'CARDING CHAIN', 'CARDING CHAIN', 'CARDING CHAIN', 'CARDING CHAIN', 'CARDING CHAIN'], 'Description (Pitch X WIP)': ['106 or 110 Links', '106 or 110 Links', '106 or 110 Links', '92 Links', '110 or 112 Links', '92 Links', '80 Links', '112 Links', '94 Links', '93 Links'], 'Price per metre': ['9678.00', '9678.00', '9678.00', '8096.00', '18531.00', '15502.00', '9927.00', '57363.00', '26494.00', '13613.00'], 'Attributes': {'Carding Machine': ['MMC, H&B, T&S, TEXTTOOL', 'PLATT BROS', 'TOYADA M&N/ D&B', 'TOYADA M&N/ D&B', 'LAKSHMI TEITER-C1/3. LC 100', 'LMW LC-300', 'TRUMAC CARD DK 740', 'RIETER C4', 'LMW LC-300A (NEW)', 'LMW LC- 300A (OLD)']}}

# %%
#Table_5 : Delta Chains (single strand,american standard simplex)

single_strand_delta_chains = []
american_standard_simplex = []

current_category = None

for sublist in table_5:
    if sublist[0] == 'SINGLE STRAND: BS ROLLER CHAINS':
        current_category = single_strand_delta_chains
    elif sublist[0] == 'AMERICAN STANDARD: SIMPLEX':
        current_category = american_standard_simplex
    else:
        current_category.append(sublist)

# dict5 is for delta chains which consists of 2 strands

#Assuming the dictionary is already defined
dict5 = {'ID': [], 'Title': [], "Description": {"In mm":[],"In Inches":[]}, "Price per metre": [], "Attributes": {"Strand Type":[],"Price Per 10ft length": []}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists, strand_type):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict5['ID'].append(sublist[0])
        dict5['Title'].append(sublist[1])
        dict5['Description']['In mm'].append(sublist[2])
        dict5['Description']['In Inches'].append(sublist[3])
        dict5['Price per metre'].append(sublist[4])
        # Adding Strand Type
        dict5['Attributes']['Strand Type'].append(strand_type)
        dict5['Attributes']['Price Per 10ft length'].append(sublist[5])
#         dict5['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
#         dict5['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])
# Adding values from single_strand_lists

add_values_to_dict(single_strand_delta_chains, 'SINGLE STRAND: BS ROLLER CHAINS')

# Adding values from double_strand_lists
add_values_to_dict(american_standard_simplex, 'AMERICAN STANDARD: SIMPLEX')

# Printing the updated dictionary
print(dict5)
# Out:
# {'ID': ['XD08301', 'XD10101', 'XD12001', 'XD16001', 'XD20001', 'XQ08A01', 'XQ10201', 'XQ12101', 'XQ16101', 'XQ20101'], 'Title': ['DELTA CHAINS', 'DELTA CHAINS', 'DELTA CHAINS', 'DELTA CHAINS', 'DELTA CHAINS', 'DELTA CHAINS', 'DELTA CHAINS', 'DELTA CHAINS', 'DELTA CHAINS', 'DELTA CHAINS'], 'Description': {'In mm': ['12.70 x 7.75', '15.88 x 9.65', '19.05 x 11.68', '25.40 x 17.02', '31.75 x 19.56', '12.70 x 7.85', '15.88 x 9.40', '19.05 x 12.58', '25.40 x 15.75', '31.75 x 18.90'], 'In Inches': ['1/2 x 5/16', '5/8 x 3/8', '3/4 x 7/16', '1 x 11/16', '1¼ x 0.77', '1/2 x 5/16', '5/8 x 3/8', '3/4 x 1/2', '1 x 5/8', '1¼ x 3/4']}, 'Price per metre': ['728.00', '841.00', '1156.00', '2243.00', '3178.00', '841.00', '1049.00', '1717.00', '2549.00', '3827.00'], 'Attributes': {'Strand Type': ['SINGLE STRAND: BS ROLLER CHAINS', 'SINGLE STRAND: BS ROLLER CHAINS', 'SINGLE STRAND: BS ROLLER CHAINS', 'SINGLE STRAND: BS ROLLER CHAINS', 'SINGLE STRAND: BS ROLLER CHAINS', 'AMERICAN STANDARD: SIMPLEX', 'AMER
# ...

# %%
#Table_6 : Bush Chains (single strand,double strand)

single_strand_bush_chains = []
doublestrand_bush_chains = []

current_category = None

for sublist in table_6:
    if sublist[0] == 'SINGLE STRAND':
        current_category = single_strand_bush_chains
    elif sublist[0] == 'DOUBLESTRAND':
        current_category = doublestrand_bush_chains
    else:
        current_category.append(sublist)

# dict6 is for delta chains which consists of 2 strands

#Assuming the dictionary is already defined
dict6 = {'ID': [], 'Title': [], "Description": {"In mm":[],"In Inches":[]}, "Price per metre": [], "Attributes": {"Strand Type":[],"Price Per 10ft length": []}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists, strand_type):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict6['ID'].append(sublist[0])
        dict6['Title'].append(sublist[1])
        dict6['Description']['In mm'].append(sublist[2])
        dict6['Description']['In Inches'].append(sublist[3])
        dict6['Price per metre'].append(sublist[4])
        # Adding Strand Type
        dict6['Attributes']['Strand Type'].append(strand_type)
        dict6['Attributes']['Price Per 10ft length'].append(sublist[5])
#         dict5['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
#         dict5['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])
# Adding values from single_strand_lists

add_values_to_dict(single_strand_bush_chains, 'SINGLE STRAND')

# Adding values from double_strand_lists
add_values_to_dict(doublestrand_bush_chains, 'DOUBLESTRAND')

# Printing the updated dictionary
print(dict6)
# Out:
# {'ID': ['B04A01', 'B04H01', 'B06101', 'B06201', 'B06A01', 'B08301', 'D08G01', 'B10101', 'B12001', 'B16001', 'B20001', 'B24001', 'B06102', 'B06A02', 'B06202', 'B06602'], 'Title': ['BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS', 'BUSH CHAINS'], 'Description': {'In mm': ['6.35 x 3.18', '', '9.53 x 5.72', '', '9.53 x 4.68', '12.70 x 7.75', '', '15.88 x 9.65', '19.05 x 11.68', '25.40 x 17.02', '31.75 x 19.56', '38.10 x 25.40', '9.53 x 5.72', '9.53 x 4.68', '9.53 x 4.76', '9.53 x 5.56'], 'In Inches': ['¼ x ⅛', '', '3/8 x 7/32', '', '3/8 x 3/16', '1/2 x 5/16', '', '5/8 x 3/8', '3/4 x 7/16', '1 x 1 1/16', '1¼ x .77', '1½ x 1', '3/8 x 7/32', '3/8 x 3/16', '3/8 x 5/16', '3/8 x 3/8']}, 'Price per metre': ['993.00', '1105.00', '459.00', '490.00', '520.00', '552.00', '654.00', '644.00', '824.00', '1570.00', '1962.00', '379
# ...

# %%
#Table_7 : Leaf Chain(no strands)


dict7 = {'ID': [], 'Title': [], "Description (Pitch X WIP)": [], "Price per metre": [], "Attributes": {"Price per 10ft length": []}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict7['ID'].append(sublist[0])
        dict7['Title'].append(sublist[1])
        dict7['Description (Pitch X WIP)'].append(sublist[2])
        #dict4['Description']['In Inches'].append(sublist[3])
        dict7['Price per metre'].append(sublist[3])
        # Adding Strand Type
#         dict3['Attributes']['Strand Type'].append(strand_type)
        dict7['Attributes']['Price per 10ft length'].append(sublist[4])
#         dict3['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
#         dict3['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])

add_values_to_dict(table_7)


# Printing the updated dictionary
print(dict7)
# Out:
# {'ID': ['DL1064', 'BL0822', 'BL0823', 'BL0834', 'BL0844', 'BL0846', 'BL0866', 'BL1022', 'BL1023', 'BL1034', 'BL1044', 'BL1046', 'BL1066', 'BL1222', 'BL1223', 'BL1234', 'BL1244', 'BL1246', 'BL1266', 'BL1622', 'BL1623', 'BL1634', 'BL1644', 'BL1646', 'BL1666', 'BL2022', 'BL2023', 'BL2034', 'BL2044', 'BL2046', 'BL2066', 'BL2422', 'BL2423', 'BL2434', 'BL2446', 'BL2466', 'LL1022', 'LL1023', 'LL1034', 'LL1044', 'LL1046', 'LL1066', 'LL1222', 'LL1223', 'LL1234', 'LL1244', 'LL1246', 'LL1265', 'LL1266', 'LL1622', 'LL1623', 'LL1634', 'LL1644', 'LL1646', 'LL1666', 'LL2044', 'LL2066', 'LL2444', 'LL2466'], 'Title': ['LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN', 'LEAF CHAIN
# ...

# %%
#Table_8 : Extended Pitch Chain(no strands)


dict8 = {'ID': [], 'Title': [], "Description (Pitch X WIP)": [], "Price per metre": [], "Attributes": {"Price per 10ft length": []}}


# Function to add values to the dictionary

def add_values_to_dict(strand_lists):
    for sublist in strand_lists:
        # Append values to the dictionary
        dict8['ID'].append(sublist[0])
        dict8['Title'].append(sublist[1])
        dict8['Description (Pitch X WIP)'].append(sublist[2])
        #dict4['Description']['In Inches'].append(sublist[3])
        dict8['Price per metre'].append(sublist[3])
        # Adding Strand Type
#         dict3['Attributes']['Strand Type'].append(strand_type)
        dict8['Attributes']['Price per 10ft length'].append(sublist[4])
#         dict3['Attributes']['Spares MRP per number']['CL'].append(sublist[6])
#         dict3['Attributes']['Spares MRP per number']['SZL'].append(sublist[7])

add_values_to_dict(table_8)


# Printing the updated dictionary
print(dict8)
# Out:
# {'ID': ['A08A01', 'A08A02', 'A10201', 'A10202', 'A12101', 'A12102', 'A12201', 'A12202', 'A16101', 'A16102', 'A16201', 'A16202', 'A20101', 'A20102', 'A20201', 'A20202'], 'Title': ['EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN', 'EXTENDED PITCH CHAIN'], 'Description (Pitch X WIP)': ['25.40 x 7.85 STD. ROLLER', '25.40 x 7.85 LARGE ROLLER', '31.75 x 9.40 STD. ROLLER', '31.75 x 9.40 LARGE ROLLER', '38.10 x 12.58 STD. ROLLER', '38.10 x 12.58 LARGE ROLLER', '38.10 x 12.58 STD. ROLLER', '38.10 x 12.58 LARGE ROLLER', '50.80 x 15.75 STD. ROLLER', '50.80 x 15.75 LARGE ROLLER', '50.80 x 15.75 STD. ROLLER', '50.80 x 15.75 LARGE ROLLER', '63.50 x 18.90 STD. ROLLER', '63.50 x 18.90 LARGE ROLL
# ...
